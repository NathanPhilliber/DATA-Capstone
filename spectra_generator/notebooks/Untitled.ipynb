# %%
# %cd ..
# Out:
# /Users/mateoibarguen/Desktop/DATA-Capstone/spectra_generator

# %%
from spectra_generator import SpectraGenerator
import pickle

# %%
spectra_generator = SpectraGenerator(n_max_s=0.0)

# %%
spectrum = spectra_generator.generate_spectrum()

# %%
spectrum.plot_channels()

# %%
spectra_generator.generate_save_spectra(10000, "data/spectra_01.pkl")

# %%
file = open("data/spectra_01.pkl",'rb')
spectra = pickle.load(file)

# %%
len(spectra)
# Out:
# 10000

# %%
spectra_df = pd.DataFrame(spectra)

# %%
spectra_np = spectra_df[['dm', 'peak_locations']].to_numpy()

# %%
spectra_np.T.shape
# Out:
# (2, 10000)
