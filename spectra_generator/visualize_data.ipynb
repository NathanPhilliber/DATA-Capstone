# %% [markdown]
# # Visualize Spectrums

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("data.csv", skiprows=1, header=None)
num_peaks = int(pd.read_csv("data.csv", nrows=1, header=None)[0])

# %%
plt.plot(df.loc[0])
plt.show()
